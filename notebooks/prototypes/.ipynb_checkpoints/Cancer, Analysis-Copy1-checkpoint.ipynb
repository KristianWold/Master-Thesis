# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from sklearn.decomposition import PCA
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

np.set_printoptions(precision=4, suppress=None)

# %% [markdown]
# # Trainability

# %% [markdown]
# ## Cancer

# %% [markdown]
# ### Three First Features

# %%
qnn_list = loader(data_path("cancer_qnn_three_first"))
dnn_list = loader(data_path("cancer_dnn_three_first"))

# %%
loss1 = np.array([model.loss for model in qnn_list])
std1 = np.std(loss1, axis=0)
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([model.loss for model in dnn_list])
std2 = np.std(loss2, axis=0)
avg2 = np.mean(loss2, axis=0)

# %%
start = 0
stop = 101
alpha = 0.5
spacing1 = list(range(101))
spacing2 = list(range(stop))

fig=plt.figure(figsize=(6,4), dpi= 130, facecolor='w', edgecolor='k')

plt.fill_between(spacing1, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(spacing2, (avg2 - std2)[:stop], (avg2 + std2)[:stop], alpha=alpha)
plt.plot(spacing1, avg1)
plt.plot(spacing2, avg2[:stop])
plt.grid()

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QNN", "DNN"])
plt.show()

# %% [markdown]
# ### Most Correlated

# %%
qnn_list = loader(data_path("cancer_qnn_most_correlated"))
dnn_list = loader(data_path("cancer_dnn_most_correlated"))

# %%
loss1 = np.array([model.loss for model in qnn_list])
std1 = np.std(loss1, axis=0)
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([model.loss for model in dnn_list])
std2 = np.std(loss2, axis=0)
avg2 = np.mean(loss2, axis=0)

# %%
start = 0
stop = 101
alpha = 0.5
spacing1 = list(range(101))
spacing2 = list(range(stop))

fig=plt.figure(figsize=(6,4), dpi= 130, facecolor='w', edgecolor='k')

plt.fill_between(spacing1, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(spacing2, (avg2 - std2)[:stop], (avg2 + std2)[:stop], alpha=alpha)
plt.plot(spacing1, avg1)
plt.plot(spacing2, avg2[:stop])
plt.grid()

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QNN", "DNN"])
plt.show()

# %%
print(avg1[-1])
print(avg2[-1])
# Out:
# 0.0385216743125
# 0.04442166336420379

# %%
print(qnn_list[0].weight)
# Out:
# [array([[ 2.2935,  5.4782,  4.2047],
#        [ 3.9774,  0.9487,  0.9357],
#        [ 0.5621,  6.934 ,  3.6379],
#        [ 4.6154, -0.2551,  5.8369],
#        [ 5.3164,  2.7747,  2.0478],
#        [ 2.023 ,  2.6422,  2.8327]]), array([[3.4709],
#        [0.8901],
#        [4.2984],
#        [0.6104],
#        [1.1806],
#        [2.2872]])]
