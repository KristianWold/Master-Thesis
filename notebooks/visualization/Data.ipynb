# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from tqdm.notebook import tqdm
import multiprocessing as mp

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Trainability, Ideal

# %% [markdown]
# ## 1D, Gaussian Function

# %%
x, y = generate_1D_mixed_gaussian()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')
plt.plot(x, y, 'o')
plt.xlabel("x")
plt.ylabel("y")
plt.grid()
fig.savefig(image_path("gaussian_1D.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2D function

# %%
n = 12
x, y = generate_2D_mixed_gaussian()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')
plt.imshow(y.reshape(n,n), extent=extent)
plt.xlabel("x1")
plt.ylabel("x2")
plt.colorbar(label="y")
fig.savefig(image_path("gaussian_2D.pdf"), bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3D function

# %%
n = 6
x, y = generate_3D_mixed_gaussian()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')
plt.imshow(y.reshape(n,n,n)[1], extent = [0, 1, 0, 1])
plt.xlabel("x1")
plt.ylabel("x2")
plt.colorbar(label="y")
fig.savefig(image_path("gaussian_3D_1.pdf"), bbox_inches='tight')
plt.show()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')
plt.imshow(y.reshape(n,n,n)[4], extent=[0, 1, 0, 1])
plt.xlabel("x1")
plt.ylabel("x2")
plt.colorbar(label="y")
fig.savefig(image_path("gaussian_3D_2.pdf"), bbox_inches='tight')
plt.show()
