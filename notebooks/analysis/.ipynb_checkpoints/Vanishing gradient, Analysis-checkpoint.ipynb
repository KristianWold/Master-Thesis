# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from tqdm.notebook import tqdm



import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from costfunction import *
from analysis import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
np.set_printoptions(precision=3)

# %% [markdown]
# # Vanishing Gradient, Data Generation

# %%
n=1
d=10
models = loader(data_path("vanishing_grad_reps_2"))

grad_average = np.array([np.mean(np.abs(grad)) for grad in models[0].weight_gradient_list]).reshape(1,-1)
input_partial = []
weight_partial = []
for layer in models[0].layers:
    input_partial.append(np.mean(np.abs(layer.input_partial)))
    weight_partial.append(np.mean(np.abs(layer.weight_partial)))
    
input_partial = np.array(input_partial)
input_partial_avg = np.mean(input_partial)

weight_partial = np.array(weight_partial)
weight_partial_avg = np.mean(weight_partial)

# %%
mean = np.mean(grad_average, axis=0)
std = np.std(grad_average, axis=0)/np.sqrt(n)

log_mean = np.log10(mean)
log_std = np.log10(mean + std) - np.log10(mean)


spacing = list(range(d))
alpha = 0.5

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
plt.plot(spacing, log_mean, label="Gradient")

plt.plot(spacing[1:], np.log(input_partial[1:]), "o", label="Input Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(input_partial_avg), np.log(input_partial_avg)] , "--", color="orange")
plt.plot(spacing, np.log(weight_partial), "o", label="Weight Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(weight_partial_avg),np.log(weight_partial_avg)] , "--", color="green")


plt.xlabel("Layer")
plt.ylabel("Mean Gradient")
plt.legend()
plt.show()

# %%
n=1
d=8
models = loader(data_path("vanishing_grad_width_5_reps_2"))

grad_average = np.array([np.mean(np.abs(grad)) for grad in models[0].weight_gradient_list]).reshape(1,-1)
input_partial = []
weight_partial = []
for layer in models[0].layers:
    input_partial.append(np.mean(np.abs(layer.input_partial)))
    weight_partial.append(np.mean(np.abs(layer.weight_partial)))
    
input_partial = np.array(input_partial)
input_partial_avg = np.mean(input_partial)

weight_partial = np.array(weight_partial)
weight_partial_avg = np.mean(weight_partial)

# %%
mean = np.mean(grad_average, axis=0)
std = np.std(grad_average, axis=0)/np.sqrt(n)

log_mean = np.log10(mean)
log_std = np.log10(mean + std) - np.log10(mean)


spacing = list(range(d))
alpha = 0.5

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
plt.plot(spacing, log_mean, label="Gradient")

plt.plot(spacing[1:], np.log(input_partial[1:]), "o", label="Input Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(input_partial_avg), np.log(input_partial_avg)] , "--", color="orange")
plt.plot(spacing, np.log(weight_partial), "o", label="Weight Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(weight_partial_avg),np.log(weight_partial_avg)] , "--", color="green")


plt.xlabel("Layer")
plt.ylabel("Mean Gradient")
plt.legend()
plt.show()

# %%
n=1
d=8
models = loader(data_path("vanishing_grad_width_6_reps_2"))

grad_average = np.array([np.mean(np.abs(grad)) for grad in models[0].weight_gradient_list]).reshape(1,-1)
input_partial = []
weight_partial = []
for layer in models[0].layers:
    input_partial.append(np.mean(np.abs(layer.input_partial)))
    weight_partial.append(np.mean(np.abs(layer.weight_partial)))
    
input_partial = np.array(input_partial)
input_partial_avg = np.mean(input_partial)

weight_partial = np.array(weight_partial)
weight_partial_avg = np.mean(weight_partial)

# %%
mean = np.mean(grad_average, axis=0)
std = np.std(grad_average, axis=0)/np.sqrt(n)

log_mean = np.log10(mean)
log_std = np.log10(mean + std) - np.log10(mean)


spacing = list(range(d))
alpha = 0.5

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
plt.plot(spacing, log_mean, label="Gradient")

plt.plot(spacing[1:], np.log(input_partial[1:]), "o", label="Input Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(input_partial_avg), np.log(input_partial_avg)] , "--", color="orange")
plt.plot(spacing, np.log(weight_partial), "o", label="Weight Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(weight_partial_avg),np.log(weight_partial_avg)] , "--", color="green")


plt.xlabel("Layer")
plt.ylabel("Mean Gradient")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5d2972f07fde> in <module>
#      10
#      11 fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
# ---> 12 plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
#      13 plt.plot(spacing, log_mean, label="Gradient")
#      14
#
# ~/anaconda3/envs/env_qiskit/lib/python3.9/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2636         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2637         data=None, **kwargs):
# -> 2638     return gca().fill_between(
#    2639         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2640         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/anaconda3/envs/env_qiskit/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/env_qiskit/lib/python3.9/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5299     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5300                      step=None, **kwargs):
# -> 5301         return self._fill_between_x_or_y(
#    5302             "x", x, y1, y2,
#    5303             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~/anaconda3/envs/env_qiskit/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5221                     f"must have the same size as {ind} in {func_name}(). This "
#    5222                     "will become an error %(removal)s.")
# -> 5223         where = where & ~functools.reduce(
#    5224             np.logical_or, map(np.ma.getmask, [ind, dep1, dep2]))
#    5225
#
# ValueError: operands could not be broadcast together with shapes (10,) (8,)

# %%
n=1
d=8
models = loader(data_path("vanishing_grad_width_7_reps_2"))

grad_average = np.array([np.mean(np.abs(grad)) for grad in models[0].weight_gradient_list]).reshape(1,-1)
input_partial = []
weight_partial = []
for layer in models[0].layers:
    input_partial.append(np.mean(np.abs(layer.input_partial)))
    weight_partial.append(np.mean(np.abs(layer.weight_partial)))
    
input_partial = np.array(input_partial)
input_partial_avg = np.mean(input_partial)

weight_partial = np.array(weight_partial)
weight_partial_avg = np.mean(weight_partial)

# %%
mean = np.mean(grad_average, axis=0)
std = np.std(grad_average, axis=0)/np.sqrt(n)

log_mean = np.log10(mean)
log_std = np.log10(mean + std) - np.log10(mean)


spacing = list(range(d))
alpha = 0.5

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
plt.plot(spacing, log_mean, label="Gradient")

plt.plot(spacing[1:], np.log(input_partial[1:]), "o", label="Input Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(input_partial_avg), np.log(input_partial_avg)] , "--", color="orange")
plt.plot(spacing, np.log(weight_partial), "o", label="Weight Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(weight_partial_avg),np.log(weight_partial_avg)] , "--", color="green")


plt.xlabel("Layer")
plt.ylabel("Mean Gradient")
plt.legend()
plt.show()

# %%
n=1
d=8
models = loader(data_path("vanishing_grad_width_8_reps_2"))

grad_average = np.array([np.mean(np.abs(grad)) for grad in models[0].weight_gradient_list]).reshape(1,-1)
input_partial = []
weight_partial = []
for layer in models[0].layers:
    input_partial.append(np.mean(np.abs(layer.input_partial)))
    weight_partial.append(np.mean(np.abs(layer.weight_partial)))
    
input_partial = np.array(input_partial)
input_partial_avg = np.mean(input_partial)

weight_partial = np.array(weight_partial)
weight_partial_avg = np.mean(weight_partial)

# %%
mean = np.mean(grad_average, axis=0)
std = np.std(grad_average, axis=0)/np.sqrt(n)

log_mean = np.log10(mean)
log_std = np.log10(mean + std) - np.log10(mean)


spacing = list(range(d))
alpha = 0.5

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.fill_between(spacing, log_mean - log_std, log_mean + log_std, alpha=alpha)
plt.plot(spacing, log_mean, label="Gradient")

plt.plot(spacing[1:], np.log(input_partial[1:]), "o", label="Input Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(input_partial_avg), np.log(input_partial_avg)] , "--", color="orange")
plt.plot(spacing, np.log(weight_partial), "o", label="Weight Partial")
plt.plot([spacing[0], spacing[-1]], [np.log(weight_partial_avg),np.log(weight_partial_avg)] , "--", color="green")


plt.xlabel("Layer")
plt.ylabel("Mean Gradient")
plt.legend()
plt.show()

# %% [markdown]
# ### Total Gradient plot  and Partial Gradient Heatmap

# %%
model1 = loader(data_path("vanishing_grad_reps_2"))
model2 = loader(data_path("vanishing_grad_width_5_reps_2"))
model3 = loader(data_path("vanishing_grad_width_6_reps_2"))
model4 = loader(data_path("vanishing_grad_width_7_reps_2"))
model5 = loader(data_path("vanishing_grad_width_8_reps_2"))

model6 = loader(data_path("vanishing_grad_dnn"))

# %%
gradient_avg = np.zeros((5, len(model2[0].layers)))
input_partial_avg = np.zeros((5, len(model2[0].layers)))
weight_partial_avg = np.zeros((5, len(model2[0].layers)))

a, b, c  = gradient_analysis(model1)
gradient_avg[0, :], input_partial_avg[0,:], weight_partial_avg[0,:] = a[2:], b[2:], c[2:] 

gradient_avg[1, :], input_partial_avg[1,:], weight_partial_avg[1,:] = gradient_analysis(model2)
gradient_avg[2, :], input_partial_avg[2,:], weight_partial_avg[2,:] = gradient_analysis(model3)
gradient_avg[3, :], input_partial_avg[3,:], weight_partial_avg[3,:] = gradient_analysis(model4)
gradient_avg[4, :], input_partial_avg[4,:], weight_partial_avg[4,:] = gradient_analysis(model5)

input_partial_avg[:,0] = float("NaN")

gradient_avg_dnn = np.zeros(8)

for model in model6:
    for i, grad in enumerate(model.weight_gradient_list):
        gradient_avg_dnn[i] += np.mean(np.abs(grad))

gradient_avg_dnn /= len(model6)

# %%
fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

x_ticks = list(range(1,9))

plt.plot(x_ticks, np.log10(gradient_avg[0]))
plt.plot(x_ticks, np.log10(gradient_avg[1]))
plt.plot(x_ticks, np.log10(gradient_avg[2]))
plt.plot(x_ticks, np.log10(gradient_avg[3]))
plt.plot(x_ticks, np.log10(gradient_avg[4]))
plt.plot(x_ticks, np.log10(gradient_avg_dnn))
plt.xlabel("Layer")
plt.ylabel("log(|gradiant|)")
plt.legend(["4 Qubits", "5 Qubits", "6 Qubits", "7 Qubits", "8 Qubits", "DNN"])
plt.grid()

fig.savefig(image_path("vanishing_gradient_total.pdf"), bbox_inches='tight')

plt.show()

# %%
fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

plt.imshow(np.log(weight_partial_avg), extent=[0.5,8.5,8.5,3.5])
plt.xlabel("Layer")
plt.ylabel("Qubits")
plt.colorbar(label="log10(|gradiant|)")

fig.savefig(image_path("vanishing_gradient_partial_weight.pdf"), bbox_inches='tight')
plt.show()

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')
plt.imshow(np.log(input_partial_avg), extent=[0.5,8.5,8.5,3.5])
plt.xlabel("Layer")
plt.ylabel("Qubits")
plt.colorbar(label="log10(|gradiant|)")

fig.savefig(image_path("vanishing_gradient_partial_input.pdf"), bbox_inches='tight')
plt.show()

# %%
fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

x = np.arange(4,9)
y1 = np.log(np.mean(weight_partial_avg, axis=1))
y2 = np.log(np.mean(input_partial_avg[:,1:], axis=1))


a1, b1 = np.polyfit(x, y1, 1)
a2, b2 = np.polyfit(x, y2, 1)

plt.plot(x, y1, "o")
plt.plot(x, a1*x + b1)

plt.plot(x, y2, "o")
plt.plot(x, a2*x + b2)

plt.xlabel("Qubits")
plt.ylabel("log10(|gradiant|)")
plt.legend(["$\\frac{\\partial a_{i}}{\\partial a_{i-1}}$", f"y = {a1:.2f}x + {b1:.2f}", "$\\frac{\\partial a_{i}}{\\partial w_{i}}$", f"y = {a2:.2f}x + {b2:.2f}"])
plt.xticks([4, 5, 6, 7, 8])

plt.grid()

fig.savefig(image_path("vanishing_gradient_fit.pdf"), bbox_inches='tight')
plt.show()

# %%
model1 = loader(data_path("vanishing_grad_width_4_reps_2_lastbit"))
model2 = loader(data_path("vanishing_grad_width_8_reps_2_lastbit"))
model3 = loader(data_path("vanishing_grad_width_12_reps_2_lastbit"))

# %%
grad1, input1, _ = gradient_analysis(model1)
grad2, input2, _ = gradient_analysis(model2)
grad3, input3, _ = gradient_analysis(model3)

# %%
plt.plot(np.log10(grad1))
plt.plot(np.log10(grad2))
plt.plot(np.log10(grad3))
plt.show()

# %%
plt.plot(np.log10(input1))
plt.plot(np.log10(input2))
plt.show()
# Out:
# <ipython-input-21-b045862662c7>:1: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(input1))
# <ipython-input-21-b045862662c7>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(np.log10(input2))
