# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from sklearn.decomposition import PCA
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
#from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # PCA

# %% [markdown]
# ### Boston

# %%
qcn_list = loader(data_path("boston_qcn"))
dnn_list = loader(data_path("boston_dnn_pca"))

# %%
loss1 = np.array([qcn.loss for qcn in qcn_list])
std1 = np.std(loss1, axis=0)/2
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([dnn.loss for dnn in dnn_list])
std2 = np.std(loss2, axis=0)/2
avg2 = np.mean(loss2, axis=0)

loss3 = np.array([qcn.loss_test for qcn in qcn_list])
std3 = np.std(loss3, axis=0)/2
avg3 = np.mean(loss3, axis=0)

loss4 = np.array([dnn.loss_test for dnn in dnn_list])
std4 = np.std(loss4, axis=0)/2
avg4 = np.mean(loss4, axis=0)

# %%
alpha = 0.2
epochs = list(range(101))

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

plt.fill_between(epochs, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(epochs, avg2 - std2, avg2 + std2, alpha=alpha)
plt.fill_between(epochs, avg3 - std3, avg3 + std3, alpha=alpha)
plt.fill_between(epochs, avg4 - std4, avg4 + std4, alpha=alpha)
plt.plot(epochs, avg1)
plt.plot(epochs, avg2)
plt.plot(epochs, avg3)
plt.plot(epochs, avg4)

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QCN Train", "DNN Train", "QCN Test", "DNN Test"])
plt.grid()
plt.ylim([0, 0.1])
plt.show()

fig.savefig(image_path("Boston_PCA.pdf"), bbox_inches='tight')

# %%
print(f"QCN train: {np.min(avg1):.3f}, DNN train:  {np.min(avg2):.3f}")
print(f"QCN test: {np.min(avg3):.3f}, DNN test:  {np.min(avg4):.3f}")
# Out:
# QCN train: 0.004, DNN train:  0.006
# QCN test: 0.043, DNN test:  0.052

# %% [markdown]
# ### Breast Cancer

# %%
qcn_list = loader(data_path("cancer_qcn"))
dnn_list = loader(data_path("cancer_dnn_pca"))

# %%
loss1 = np.array([qcn.loss for qcn in qcn_list])
std1 = np.std(loss1, axis=0)/2
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([dnn.loss for dnn in dnn_list])
std2 = np.std(loss2, axis=0)/2
avg2 = np.mean(loss2, axis=0)

loss3 = np.array([qcn.loss_test for qcn in qcn_list])
std3 = np.std(loss3, axis=0)/2
avg3 = np.mean(loss3, axis=0)

loss4 = np.array([dnn.loss_test for dnn in dnn_list])
std4 = np.std(loss4, axis=0)/2
avg4 = np.mean(loss4, axis=0)

# %%
alpha = 0.2
epochs = list(range(101))

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

plt.fill_between(epochs, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(epochs, avg2 - std2, avg2 + std2, alpha=alpha)
plt.fill_between(epochs, avg3 - std3, avg3 + std3, alpha=alpha)
plt.fill_between(epochs, avg4 - std4, avg4 + std4, alpha=alpha)
plt.plot(epochs, avg1)
plt.plot(epochs, avg2)
plt.plot(epochs, avg3)
plt.plot(epochs, avg4)

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QCN Train", "DNN Train", "QCN Test", "DNN Test"])
plt.grid()
plt.ylim([0, 0.1])
plt.show()

fig.savefig(image_path("Cancer_PCA.pdf"), bbox_inches='tight')

# %%
print(f"QCN train: {np.min(avg1):.3f}, DNN train:  {np.min(avg2):.3f}")
print(f"QCN test: {np.min(avg3):.3f}, DNN test:  {np.min(avg4):.3f}")
# Out:
# QCN train: 0.0278, DNN train:  0.0011
# QCN test: 0.0577, DNN test:  0.0319

# %% [markdown]
# # Hybrid

# %% [markdown]
# ## Boston

# %%
qcn_list = loader(data_path("boston_hybrid"))
dnn_list = loader(data_path("boston_dnn_full"))

# %%
loss1 = np.array([qcn.loss for qcn in qcn_list])
std1 = np.std(loss1, axis=0)/2
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([dnn.loss for dnn in dnn_list])
std2 = np.std(loss2, axis=0)/2
avg2 = np.mean(loss2, axis=0)

loss3 = np.array([qcn.loss_test for qcn in qcn_list])
std3 = np.std(loss3, axis=0)/2
avg3 = np.mean(loss3, axis=0)

loss4 = np.array([dnn.loss_test for dnn in dnn_list])
std4 = np.std(loss4, axis=0)/2
avg4 = np.mean(loss4, axis=0)

# %%
alpha = 0.2
epochs = list(range(101))

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

plt.fill_between(epochs, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(epochs, avg2 - std2, avg2 + std2, alpha=alpha)
plt.fill_between(epochs, avg3 - std3, avg3 + std3, alpha=alpha)
plt.fill_between(epochs, avg4 - std4, avg4 + std4, alpha=alpha)
plt.plot(epochs, avg1)
plt.plot(epochs, avg2)
plt.plot(epochs, avg3)
plt.plot(epochs, avg4)

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QCN Train", "DNN Train", "QCN Test", "DNN Test"])
plt.grid()
plt.ylim([0, 0.05])
plt.show()

fig.savefig(image_path("Boston_Hybrid.pdf"), bbox_inches='tight')

# %%
print(f"QCN train: {np.min(avg1):.3f}, DNN train:  {np.min(avg2):.3f}")
print(f"QCN test: {np.min(avg3):.3f}, DNN test:  {np.min(avg4):.3f}")
# Out:
# QCN train: 0.004, DNN train:  0.002
# QCN test: 0.021, DNN test:  0.011

# %% [markdown]
# ## Breast Cancer

# %%
qcn_list = loader(data_path("cancer_hybrid"))
dnn_list = loader(data_path("cancer_dnn_full"))

# %%
loss1 = np.array([qcn.loss for qcn in qcn_list])
std1 = np.std(loss1, axis=0)/2
avg1 = np.mean(loss1, axis=0)

loss2 = np.array([dnn.loss for dnn in dnn_list])
std2 = np.std(loss2, axis=0)/2
avg2 = np.mean(loss2, axis=0)

loss3 = np.array([qcn.loss_test for qcn in qcn_list])
std3 = np.std(loss3, axis=0)/2
avg3 = np.mean(loss3, axis=0)

loss4 = np.array([dnn.loss_test for dnn in dnn_list])
std4 = np.std(loss4, axis=0)/2
avg4 = np.mean(loss4, axis=0)

# %%
alpha = 0.2
epochs = list(range(101))

fig=plt.figure(figsize=(6,4), dpi=130, facecolor='w', edgecolor='k')

plt.fill_between(epochs, avg1 - std1, avg1 + std1, alpha=alpha)
plt.fill_between(epochs, avg2 - std2, avg2 + std2, alpha=alpha)
plt.fill_between(epochs, avg3 - std3, avg3 + std3, alpha=alpha)
plt.fill_between(epochs, avg4 - std4, avg4 + std4, alpha=alpha)
plt.plot(epochs, avg1)
plt.plot(epochs, avg2)
plt.plot(epochs, avg3)
plt.plot(epochs, avg4)

plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.legend(["QCN Train", "DNN Train", "QCN Test", "DNN Test"])
plt.grid()
plt.ylim([0, 0.2])
plt.show()

fig.savefig(image_path("Cancer_Hybrid.pdf"), bbox_inches='tight')

# %%
print(f"QCN train: {np.min(avg1):.3f}, DNN train:  {np.min(avg2):.3f}")
print(f"QCN test: {np.min(avg3):.3f}, DNN test:  {np.min(avg4):.3f}")
# Out:
# QCN train: 0.035, DNN train:  0.000
# QCN test: 0.102, DNN test:  0.030
