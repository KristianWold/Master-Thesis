# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from sklearn.decomposition import PCA
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *
from utils import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tl = loader(data_path("tl_expressivity_width_4_reps_2"))

# %%
plt.plot([np.log(x) for x in tl.trajectory_length])
plt.show()

for x_proj in tl.trajectory_projection:  
    plt.plot(x_proj[:,0], x_proj[:,1])
    plt.xlim([-np.pi, np.pi])
    plt.ylim([-np.pi, np.pi])
    plt.show()

# %%
network_dnn = loader(data_path("network_expressivity_width_4_dnn"))

# %%
pca = PCA(n_components=2)
x = network_dnn.a[7]

x_proj = pca.fit_transform(x)

print(trajectory_length(x))
plt.plot(x_proj[:,0], x_proj[:,1])
plt.show()
# Out:
# 1.069049758081368e-05
