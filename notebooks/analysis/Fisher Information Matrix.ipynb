# %%
import numpy as np
import qiskit as qk
import matplotlib.pyplot as plt
from qiskit import Aer
from tqdm.notebook import tqdm

import sys
sys.path.insert(0, '../../src/')
from neuralnetwork import *
from analysis import *

#%matplotlib notebook
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Fisher Information Matrix, Analysis

# %%
fim1 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_2_width_5_reps_2_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_2_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')
plt.plot(np.log10(eigen1), "o")
plt.plot(np.log10(eigen2), "o")
plt.plot(np.log10(eigen3), "o")
plt.xlabel("Index")
plt.ylabel("log10 Eigenvalue")
plt.legend(["QKN with L=2, d=5, reps=1", "QKN with L=2, d=5, reps=2", "DNN with L=2, d=5"])
plt.grid()

plt.show()
fig.savefig(image_path("FIM_layer_2.pdf"), bbox_inches='tight')

# %%
fim1 = loader(data_path("fim_QNN_depth_3_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_3_width_5_reps_2_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_3_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')

plt.plot(np.log10(eigen1), "o")
plt.plot(np.log10(eigen2), "o")
plt.plot(np.log10(eigen3), "o")
plt.xlabel("Index")
plt.ylabel("log10 Eigenvalue")
plt.legend(["QKN with L=3, d=5, reps=1", "QKN with L=3, d=5, reps=2", " DNN with L=3, d=5"])
plt.grid()

plt.show()
fig.savefig(image_path("FIM_layer_3.pdf"), bbox_inches='tight')

# %%
fim1 = loader(data_path("fim_QNN_depth_4_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_4_width_5_reps_2_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim1.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_4_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')

plt.plot(np.log10(eigen1), "o")
plt.plot(np.log10(eigen2), "o")
plt.plot(np.log10(eigen3), "o")
plt.xlabel("Index")
plt.ylabel("log10 Eigenvalue")
plt.legend(["QKN with L=4, d=5, reps=1", "QKN with L=4, d=5, reps=2", " DNN with L=4, d=5"])
plt.grid()

plt.show()
fig.savefig(image_path("FIM_layer_4.pdf"), bbox_inches='tight')

# %%
fim1 = loader(data_path("fim_QNN_depth_5_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_5_width_5_reps_2_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim1.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_5_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

# %%
fig=plt.figure(figsize=(6,4), dpi = 130, facecolor='w', edgecolor='k')


plt.plot(np.log10(eigen1), "o")
plt.plot(np.log10(eigen2), "o")
plt.plot(np.log10(eigen3), "o")
plt.xlabel("Index")
plt.ylabel("log10 Eigenvalue")
plt.legend(["QKN with L=5, d=5, reps=1", "QKN with L=5, d=5, reps=2", "DNN with L=5, d=5"])
plt.grid()

plt.show()
fig.savefig(image_path("FIM_layer_5.pdf"), bbox_inches='tight')

# %% [markdown]
# ## Quantum Neural Network

# %% [markdown]
# ### Increasing Depth

# %%
fim1 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_3_width_5_reps_1_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_QNN_depth_4_width_5_reps_1_shots_100k"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_QNN_depth_5_width_5_reps_1_shots_100k"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

fim5 = loader(data_path("fim_QNN_depth_6_width_5_reps_1_shots_100k"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

# %%
plt.plot(np.log10(eigen1[:30]), "o")
plt.plot(np.log10(eigen2[:30]), "o")
plt.plot(np.log10(eigen3[:30]), "o")
plt.plot(np.log10(eigen4[:30]), "o")
plt.plot(np.log10(eigen5[:30]), "o")
plt.legend(["d=2","d=3", "d=4", "d=5", "d=6"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4, fr5], "o")
plt.show()

# %% [markdown]
# ### Increasing Width

# %%
fim1 = loader(data_path("fim_QNN_depth_3_width_3_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_3_width_4_reps_1_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_QNN_depth_3_width_5_reps_1_shots_100k"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_QNN_depth_3_width_6_reps_1_shots_100k"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

fim5 = loader(data_path("fim_QNN_depth_3_width_7_reps_1_shots_100k"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

fim6 = loader(data_path("fim_QNN_depth_3_width_8_reps_1_shots_100k"))
eigen6 = fim6.eigen()
fr6 = fim6.fisher_rao()

# %%
plt.plot(np.log10(eigen1[:20]), "o")
plt.plot(np.log10(eigen2[:20]), "o")
plt.plot(np.log10(eigen3[:20]), "o")
plt.plot(np.log10(eigen4[:20]), "o")
plt.plot(np.log10(eigen5[:20]), "o")
plt.plot(np.log10(eigen6[:20]), "o")
plt.legend(["w=3","w=4", "w=5", "w=6", "w=7", "w=8"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4, fr5], "o")
plt.show()

# %% [markdown]
# ### Increasing Reps

# %%
fim1 = loader(data_path("fim_QNN_depth_3_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_3_width_5_reps_2_shots_100k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_QNN_depth_3_width_5_reps_3_shots_100k"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_QNN_depth_3_width_5_reps_4_shots_100k"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()


fim5 = loader(data_path("fim_QNN_depth_3_width_5_reps_5_shots_100k"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

# %%
plt.plot(np.log10(np.abs(eigen1[:20])), "o")
plt.plot(np.log10(np.abs(eigen2[:20])), "o")
plt.plot(np.log10(np.abs(eigen3[:20])), "o")
plt.plot(np.log10(np.abs(eigen4[:20])), "o")
plt.plot(np.log10(np.abs(eigen5[:20])), "o")
plt.legend(["r=1","r=2", "r=3", "r=4", "r=5"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4, fr5], "o")
plt.show()

# %% [markdown]
# ## Classical Neural Network

# %% [markdown]
# ### Increasing Depth

# %%
fim1 = loader(data_path("fim_DNN_depth_2_width_5"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_DNN_depth_3_width_5"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_4_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_DNN_depth_5_width_5"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

fim5 = loader(data_path("fim_DNN_depth_6_width_5"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

# %%
plt.plot(np.log10(eigen1[:30]), "o")
plt.plot(np.log10(eigen2[:30]), "o")
plt.plot(np.log10(eigen3[:30]), "o")
plt.plot(np.log10(eigen4[:30]), "o")
plt.plot(np.log10(eigen5[:30]), "o")
plt.legend(["d=2","d=3", "d=4", "d=5", "d=6"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4, fr5], "o")
plt.show()

# %% [markdown]
# ### Increasing Width

# %%
fim1 = loader(data_path("fim_DNN_depth_3_width_3"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_DNN_depth_3_width_4"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_DNN_depth_3_width_5"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_DNN_depth_3_width_6"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

fim5 = loader(data_path("fim_DNN_depth_3_width_7"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

fim6 = loader(data_path("fim_DNN_depth_3_width_8"))
eigen6 = fim6.eigen()
fr6 = fim6.fisher_rao()

# %%
plt.plot(np.log10(eigen1[:20]), "o")
plt.plot(np.log10(eigen2[:20]), "o")
plt.plot(np.log10(eigen3[:20]), "o")
plt.plot(np.log10(eigen4[:20]), "o")
plt.plot(np.log10(eigen5[:20]), "o")
plt.plot(np.log10(eigen6[:20]), "o")
plt.legend(["w=3","w=4", "w=5", "w=6", "w=7", "w=8"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4, fr5], "o")
plt.show()

# %% [markdown]
# ## Sensitivity wrt Shots

# %%
fim1 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_1k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_10k"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_100k"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_1mill"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

# %%
i = 6
plt.plot(eigen1[i:i+1], "o")
plt.plot(eigen2[i:i+1], "o")
plt.plot(eigen3[i:i+1], "o")
plt.plot(eigen4[i:i+1], "o")

#plt.legend(["w=3","w=4", "w=5", "w=6", "w=7", "w=8"])
plt.show()

# %%
plt.plot([fr1, fr2, fr3, fr4], "o")
plt.show()

# %% [markdown]
# ### Comparison

# %%
fim1 = loader(data_path("fim_QNN_depth_2_width_5_reps_1_shots_100k"))
eigen1 = fim1.eigen()
fr1 = fim1.fisher_rao()

fim2 = loader(data_path("fim_DNN_depth_2_width_5"))
eigen2 = fim2.eigen()
fr2 = fim2.fisher_rao()

fim3 = loader(data_path("fim_QNN_depth_3_width_5_reps_1_shots_100k"))
eigen3 = fim3.eigen()
fr3 = fim3.fisher_rao()

fim4 = loader(data_path("fim_DNN_depth_3_width_5"))
eigen4 = fim4.eigen()
fr4 = fim4.fisher_rao()

fim5 = loader(data_path("fim_QNN_depth_4_width_5_reps_1_shots_100k"))
eigen5 = fim5.eigen()
fr5 = fim5.fisher_rao()

fim6 = loader(data_path("fim_DNN_depth_4_width_5"))
eigen6 = fim6.eigen()
fr6 = fim6.fisher_rao()

fim7 = loader(data_path("fim_QNN_depth_5_width_5_reps_1_shots_100k"))
eigen7 = fim7.eigen()
fr7 = fim7.fisher_rao()

fim8 = loader(data_path("fim_DNN_depth_5_width_5"))
eigen8 = fim8.eigen()
fr8 = fim8.fisher_rao()

# %%
plt.plot(np.log(eigen1[:20]), "o")
plt.plot(np.log(eigen2[:20]), "o")
plt.show()

plt.plot(np.log(eigen3[:20]), "o")
plt.plot(np.log(eigen4[:20]), "o")
plt.show()

plt.plot(np.log(eigen5[:20]), "o")
plt.plot(np.log(eigen6[:20]), "o")
plt.show()

plt.plot(np.log(eigen7[:20]), "o")
plt.plot(np.log(eigen8[:20]), "o")
plt.show()

# %%
plt.plot([fr1, fr3, fr5, fr7])
plt.plot([fr2, fr4, fr6, fr8])
